# %% [markdown]
# ## 1. Load Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset from csv file
df = pd.read_csv('kc_house_data.csv')

# %%
# Looking at the first 5 rows of the dataset
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## 2. Summarize Data/ Exploratory Data Analysis

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
#Distribution of Price
sns.displot(df['price'], aspect = 2)
# Out:
# C:\Users\Vybhav TK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Histogram of number of bedrooms
sns.countplot(data =df, x = 'bedrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
# Comparing the price variable to others which have high correlation with it
df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
# sqft_living has the highest correlation with the price.
# So we create a scatterplot of prics vs sqft_living

sns.scatterplot(data = df, x = 'price', y = 'sqft_living')
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(x = 'bedrooms', y ='price', data = df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
# We can look at the geographic trend of data by plotting the price against latitude and longitude
# But we don't see a clear colour gradient because of the expensive outliers in price
plt.figure(figsize = (12,8))
sns.scatterplot(data = df, x = 'long', y = 'lat', hue = 'price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
len(df)
# Out:
# 21613

# %%
# We are dropping the top 1% of the data which are the most expensive
df_99_prec = df.sort_values('price', ascending = False).iloc[216:]

# %%
# We can look at the geographic trend of data by plotting the price against latitude and longitude
# But we don't see a clear colour gradient because of the expensive outliers in price
plt.figure(figsize = (12,8))
sns.scatterplot(data = df_99_prec, x = 'long', y = 'lat', hue = 'price', edgecolor = None, alpha = 0.2, palette = 'RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
# Boxplot of whether the house is on the waterfront
# It shows the waterfront houses are more expensive
sns.boxplot(data = df, x = 'waterfront', y = 'price')
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ## 3. Prepare Data

# %%
# Drop the ID Column - does not give any meaningful information
df.drop('id', axis = 1, inplace = True)

# %%
# The date column has object datatype. 
df['date']
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
# We can convert it to date time datatype.
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
# Extract Year and month from the date
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
# Looking if we have a correlation between month of selling and house price
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
# Looking if we have a correlation between year of selling and house price
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Now drop the date column
df.drop('date', axis =1 ,inplace = True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
# If we feed the zipcode to our ML model, it will treat it as a continuous variable, which it is not in real world.
df['zipcode'].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %%
# We have 70 unique zipcode, so we can't add it as a dummy variable and add 70 extra features. 
# We will drop it here.

df.drop('zipcode', axis = 1, inplace = True)

# %%
# Latitude and Longitude do not provide direct information in terms of their numerical value.
# So we can drop them from our table.

df.drop(['lat','long'],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'sqft_living15',
#        'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %% [markdown]
# ## 4. Model Building - Pre Processing

# %%
# Separate our input and output variables
X = df.drop('price', axis = 1).values
y = df['price'].values

# %%
# Separating our data into training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Scaling our dataset
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Model Building -
# #### The following models will be used to predict the house prices -
# #### 1. Linear Regression
# #### 2. Elastic Net Regression
# #### 3. Random Forest Regression
# #### 4. Support Vector Regression
# #### 5. Neural Network Regression

# %% [markdown]
# ### 1. Linear Regression

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn import metrics  

for name,method in [('Linear Regression', LinearRegression())]: 
    method.fit(X_train,y_train)
    predict = method.predict(X_test)

print('Method: {}'.format(name))   

#Coefficents
print('\nIntercept: {:0.2f}'.format(float(method.intercept_)))
coeff_table=pd.DataFrame(np.transpose(method.coef_),df.drop('price',axis=1).columns,columns=['Coefficients'])
print('\n')
print(coeff_table)
    
#MAE,MSE and RMSE
print('\nR2: {:0.2f}'.format(metrics.r2_score(y_test, predict)))
adjusted_r_squared2 = 1-(1-metrics.r2_score(y_test,predict))*(len(y)-1)/(len(y)-X.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared2))

print('\nMean Absolute Error: {:0.2f}'.format(metrics.mean_absolute_error(y_test, predict)))  
print('Mean Squared Error: {:0.2f}'.format(metrics.mean_squared_error(y_test, predict)))  
print('Root Mean Squared Error: {:0.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, predict))))
# Out:
# Method: Linear Regression
#
# Intercept: -372277.83
#
#
#                Coefficients
# bedrooms      -1.275637e+06
# bathrooms      3.527214e+05
# sqft_living   -4.669198e+16
# sqft_lot      -4.602317e+04
# floors         6.832115e+04
# waterfront     5.416645e+05
# view           1.761382e+05
# condition      6.649865e+04
# grade          1.422732e+06
# sqft_above     3.402638e+16
# sqft_basement  1.913736e+16
# yr_built      -4.057149e+05
# yr_renovated   2.861224e+04
# sqft_living15  1.216010e+05
# sqft_lot15    -4.277131e+05
# year           3.443796e+04
# month          1.571334e+04
#
# R2: 0.65
# Adj_R2: 0.65
#
# Mean Absolute Error: 142865.83
# Mean Squared Error: 49987107332.07
# Root Mean Squared Error: 223577.97

# %% [markdown]
# ### 2. Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

for name, method in [('Elastic Net Regression', ElasticNet(alpha=1.0, l1_ratio=0.5))]: 
    method.fit(X_train, y_train)
    predict = method.predict(X_test)

print('Method: {}'.format(name))

# Coefficients
print('\nIntercept: {:0.2f}'.format(float(method.intercept_)))
coeff_table = pd.DataFrame(np.transpose(method.coef_), df.drop('price', axis=1).columns, columns=['Coefficients'])
print('\n')
print(coeff_table)

# R2 and Adjusted R2
r2 = metrics.r2_score(y_test, predict)
print('\nR2: {:0.2f}'.format(r2))
n = X_test.shape[0]  # Number of observations in the test set
p = X_test.shape[1]  # Number of predictors in the model
adjusted_r_squared = 1 - (1-r2) * (n-1) / (n-p-1)
print('Adjusted R2: {:0.2f}'.format(adjusted_r_squared))

# MAE, MSE, and RMSE
print('\nMean Absolute Error: {:0.2f}'.format(metrics.mean_absolute_error(y_test, predict)))  
print('Mean Squared Error: {:0.2f}'.format(metrics.mean_squared_error(y_test, predict)))  
print('Root Mean Squared Error: {:0.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, predict))))
# Out:
# Method: Elastic Net Regression
#
# Intercept: 462994.54
#
#
#                Coefficients
# bedrooms        5620.009634
# bathrooms      32645.663320
# sqft_living    36088.632832
# sqft_lot        2001.941983
# floors         33148.063750
# waterfront     13734.079152
# view           47843.005723
# condition       4520.142122
# grade          43033.890158
# sqft_above     38365.483655
# sqft_basement  19835.768200
# yr_built        4571.552458
# yr_renovated   17146.909520
# sqft_living15  44763.906710
# sqft_lot15      1533.675779
# year            3215.156539
# month          -1559.846096
#
# R2: 0.10
# Adjusted R2: 0.09
#
# Mean Absolute Error: 223731.12
# Mean Squared Error: 130612533190.10
# Root Mean Squared Error: 361403.56

# %% [markdown]
# ### 3. Random Forest Regression

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Initialize the Random Forest Regressor
random_forest_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
random_forest_regressor.fit(X_train, y_train)

# Predict on the testing set
y_pred = random_forest_regressor.predict(X_test)

# Calculate the metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R² Score:", r2)
# Out:
# Mean Absolute Error (MAE): 119683.25529148674
# Mean Squared Error (MSE): 40167714482.247406
# Root Mean Squared Error (RMSE): 200418.84762229177
# R² Score: 0.7217657441917656

# %% [markdown]
# ### 4. Support Vector Regression

# %%
# Import necessary libraries
from sklearn.svm import SVR
#from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Initialize the SVR model
svr_model = SVR(kernel='rbf')

# Fit the model to the training data
svr_model.fit(X_train, y_train)

# Predict on the testing set
y_pred = svr_model.predict(X_test)

# Calculate the metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R² Score:", r2)
# Out:
# Mean Absolute Error (MAE): 226695.1005171177
# Mean Squared Error (MSE): 153375540022.89844
# Root Mean Squared Error (RMSE): 391631.89352106967
# R² Score: -0.06240371869595984

# %% [markdown]
# ### 5. Neural Network

# %%
# We have 17 features as input to the neural network
X_train.shape
# Out:
# (15129, 17)

# %%
# Importing the keras libraries

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Building the Neural Network Model
# Added dropout layer for preventing overfitting

model = Sequential()

model.add(Dense(17, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(8, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(4, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(2, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation = 'linear'))

model.compile(loss = 'mse', optimizer = 'adam')

# %%
# Using Early Stopping to prevent overfitting

early_stop = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience= 6)

# %%
# Training the model on our dataset

model.fit(x = X_train, y = y_train, epochs = 500, batch_size=256, validation_data = (X_test, y_test), callbacks = [early_stop])
# Out:
# Epoch 1/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 425926492160.0000 - val_loss: 446798561280.0000
# Epoch 2/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 436645101568.0000 - val_loss: 446792007680.0000
# Epoch 3/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 419476701184.0000 - val_loss: 446754029568.0000
# Epoch 4/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 422642909184.0000 - val_loss: 446610931712.0000
# Epoch 5/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 441558859776.0000 - val_loss: 446209327104.0000
# Epoch 6/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 431939354624.0000 - val_loss: 445299097600.0000
# Epoch 7/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 411042086912.0000 - val_loss: 443542929408.0000
# Epoch 8/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 417347305472.0000 - val_loss: 440481382400.0000
# Epoch 9/500
# ...

# %%
# Importing the training and validation losses during each epoch for plotting

losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# Predict on the testing set
y_pred = model.predict(X_test)

# Calculate the metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
exp_var = explained_variance_score(y_test,y_pred)

# Print the evaluation metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Explained Variance Score:", exp_var)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Mean Absolute Error (MAE): 188206.33005824432
# Mean Squared Error (MSE): 92219569378.42932
# Root Mean Squared Error (RMSE): 303676.7514618617
# Explained Variance Score: 0.5300089864799665

# %% [markdown]
# ### Comparing the errors

# %%
# Making a dictionary from the error values
error_dict = { 
    'Algorithm': ['Linear Regression', 'Elastic Net Regression', 'Random Forest', 'Support Vector', 'Neural Network'],
    'MAE': [142865.83, 223731.12, 119683.26, 226695.10, 188206.33],
    'MSE': [49987107332.07, 130612533190.10, 40167714482.25, 153375540022.90, 92219569378.43 ],
    'RMSE': [223577.97, 361403.56, 200418.85, 391631.90, 303676.75]
}

# %%
error_df = pd.DataFrame(error_dict)

# %%
df['price'].mean()
# Out:
# 540088.1417665294

# %%
error_df
# Out:
#                 Algorithm        MAE           MSE       RMSE
# 0       Linear Regression  142865.83  4.998711e+10  223577.97
# 1  Elastic Net Regression  223731.12  1.306125e+11  361403.56
# 2           Random Forest  119683.26  4.016771e+10  200418.85
# 3          Support Vector  226695.10  1.533755e+11  391631.90
# 4          Neural Network  188206.33  9.221957e+10  303676.75

# %%
plt.figure(figsize = (10,8))
sns.lineplot(data = error_df, x = 'Algorithm', y = 'RMSE')
# Out:
# C:\Users\Vybhav TK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vybhav TK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Algorithm', ylabel='RMSE'>

# %% [markdown]
# ### Based on the error values, we will choose Linear Regression and Random Forest Regressor as our 2 best models.

# %% [markdown]
# ### Improving the model

# %% [markdown]
# ### We will do feature selection for both Linear Regression and Random Forest Regressor using RLF

# %%
#Using the linear regression model from our previous analysis
method
# Out:
# LinearRegression()

# %%
#Our training data has 17 features currently
X_train.shape
# Out:
# (15129, 17)

# %%
from sklearn.feature_selection import RFE

# Create a linear regression model as the estimator
estimator = method

# Choose the number of features you want to select
n_features_to_select = 14  # You can adjust this to your needs

# Create the RFE object and rank each pixel
selector = RFE(estimator, n_features_to_select=n_features_to_select, step=1)
selector = selector.fit(X_train, y_train)

# Features selected by RFE
selected_features = selector.support_

# Rankings of features, where rank 1 means the feature was selected
feature_ranking = selector.ranking_

# Transform X_train to the selected features
X_train_selected = selector.transform(X_train)

# %%
X_train_selected.shape
# Out:
# (15129, 14)

# %%
X_test_selected = selector.transform(X_test)
X_test_selected.shape
# Out:
# (6484, 14)

# %%
# Linear Regression

for name,method in [('Linear Regression', LinearRegression())]: 
    method.fit(X_train_selected,y_train)
    predict = method.predict(X_test_selected)

print('Method: {}'.format(name))   

    
#MAE,MSE and RMSE
print('\nR2: {:0.2f}'.format(metrics.r2_score(y_test, predict)))
adjusted_r_squared2 = 1-(1-metrics.r2_score(y_test,predict))*(len(y)-1)/(len(y)-X_train_selected.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared2))

print('\nMean Absolute Error: {:0.2f}'.format(metrics.mean_absolute_error(y_test, predict)))  
print('Mean Squared Error: {:0.2f}'.format(metrics.mean_squared_error(y_test, predict)))  
print('Root Mean Squared Error: {:0.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, predict))))
# Out:
# Method: Linear Regression
#
# R2: 0.65
# Adj_R2: 0.65
#
# Mean Absolute Error: 142872.85
# Mean Squared Error: 50115951119.47
# Root Mean Squared Error: 223865.92

# %%
random_forest_regressor
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.feature_selection import RFE

# Create a linear regression model as the estimator
estimator = random_forest_regressor

# Choose the number of features you want to select
n_features_to_select = 14  # You can adjust this to your needs

# Create the RFE object and rank each pixel
selector = RFE(estimator, n_features_to_select=n_features_to_select, step=1)
selector = selector.fit(X_train, y_train)

# Features selected by RFE
selected_features = selector.support_

# Rankings of features, where rank 1 means the feature was selected
feature_ranking = selector.ranking_

# Transform X_train to the selected features
X_train_selected = selector.transform(X_train)

# %%
X_train_selected.shape
# Out:
# (15129, 14)

# %%
X_test_selected = selector.transform(X_test)
X_test_selected.shape
# Out:
# (6484, 14)

# %%
# Fit the model to the training data
random_forest_regressor.fit(X_train_selected, y_train)

# Predict on the testing set
y_pred = random_forest_regressor.predict(X_test_selected)

# Calculate the metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R² Score:", r2)
# Out:
# Mean Absolute Error (MAE): 120306.91691239976
# Mean Squared Error (MSE): 40473532112.899704
# Root Mean Squared Error (RMSE): 201180.34723327152
# R² Score: 0.7196474025839755

# %% [markdown]
# ### Now we use Grid Search to select the best hyperparameters for Random Forest Regression

# %%
from sklearn.model_selection import GridSearchCV

# Create a Random Forest Regressor object
rf = RandomForestRegressor(random_state=42)

# Define the parameter grid to search
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider at every split
    'max_depth': [None, 10, 20, 30],  # Maximum number of levels in tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4]  # Minimum number of samples required at each leaf node
}

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, verbose=2, n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Optionally: use the best estimator to make predictions
best_rf = grid_search.best_estimator_
predictions = best_rf.predict(X_test)

# Evaluate performance or continue with further model assessment
print("Model performance on test set:", best_rf.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 324 candidates, totalling 972 fits
# Best parameters: {'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Best score: 0.7459895209670485
# Model performance on test set: 0.729897389472629

# %%
# Predict on the testing set using the best estimator

y_pred = best_rf.predict(X_test)

# Calculate the metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R² Score:", r2)
# Out:
# Mean Absolute Error (MAE): 119729.30151455171
# Mean Squared Error (MSE): 38993777056.879654
# Root Mean Squared Error (RMSE): 197468.42040407285
# R² Score: 0.729897389472629

# %% [markdown]
# ### Saving the final model

# %%
import joblib
joblib.dump(best_rf, 'random_forest_regressor.joblib')
# Out:
# ['random_forest_regressor.joblib']
